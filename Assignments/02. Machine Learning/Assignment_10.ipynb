# %% [markdown]
# **1.	Define the Bayesian interpretation of probability.**
#
# The Bayesian interpretation of probability sees probability as a measure of belief, considering both prior knowledge and new evidence. It's a flexible way to handle uncertainty, using Bayes' theorem to update beliefs based on available data. This approach guides decision-making in various fields by combining existing understanding with new information.
#
# **2.	Define probability of a union of two events with equation.**
#
# The general probability addition rule for the union of two events states that
#
# **`P(A∪B)=P(A)+P(B)−P(A∩B)`** ,
#
# where **`A∩B`** is the intersection of the two sets.
#
# **3.   What is joint probability? What is its formula?**
#
# Probabilities are combined using multiplication, therefore the joint probability of independent events is calculated as the probability of event A multiplied by the probability of event B. This can be stated formally as follows:
#
# Joint Probability: **`P(A and B) = P(A)*P(B)`**

# %% [markdown]
# **4.  What is chain rule of probability?**
#
# The chain rule, or general product rule, calculates any component of the joint distribution of a set of random variables using only conditional probabilities. This probability theory is used as a foundation for backpropagation and in creating Bayesian networks.

# %% [markdown]
# **5.	What is conditional probability means? What is the formula of it?**
#
# Conditional probability is the probability of an event occurring given that another event has occurred.
#
# Conditional probability is calculated by multiplying the probability of the preceding event by the updated probability of the succeeding, or conditional, event.
#
# ![conditional_probability.jpg](attachment:conditional_probability.jpg)
#
# Let's take a real-life example. Probability of selling a TV on a given normal day may be only 30%. But if we consider that given day is Diwali, then there are much more chances of selling a TV. The conditional Probability of selling a TV on a day given that Day is Diwali might be 70%.

# %% [markdown]
# **6.	What are continuous random variables?**
#
# Continuous random variables are variables that can take any value within a certain range, often representing measurements or quantities. They are associated with continuous probability distributions.

# %% [markdown]
# **7.	What are Bernoulli distributions? What is the formula of it?**
#
# The Bernoulli distribution models a binary outcome (success or failure) of an experiment with a fixed probability. The formula for a Bernoulli distribution with parameter p is:
#
# ![bernoli.jpg](attachment:bernoli.jpg)

# %% [markdown]
# **8.	What is binomial distribution? What is the formula?**
#
# The binomial distribution models the number of successes in a fixed number of independent Bernoulli trials. The formula for the probability of k successes in n trials with probability p of success is:
#
# ![binomial_formula.jpg](attachment:binomial_formula.jpg)

# %% [markdown]
# **9.	What is Poisson distribution? What is the formula?**
#
# The Poisson distribution models the number of events occurring in a fixed interval of time or space. The formula for the probability of k events occurring when the average rate is λ is:
#
# ![poisson%20formula.jpg](attachment:poisson%20formula.jpg)
#
#
# **10.	Define covariance.**
#
# Covariance measures the degree to which two random variables change together. It indicates whether an increase in one variable corresponds to an increase or decrease in the other. Positive covariance indicates a positive relationship, while negative covariance indicates a negative relationship.
#
# **11.	Define correlation**
#
# Correlation measures the strength and direction of the linear relationship between two random variables. It ranges from -1 (perfect negative correlation) to 1 (perfect positive correlation), with 0 indicating no linear correlation.
#
# **12.	Define sampling with replacement. Give example.**
#
# Sampling with replacement is a method of selecting items from a population where each selected item is returned to the population before the next selection. Each selection is independent of previous selections.
#
# Example: Drawing a card from a deck, putting it back, and drawing another card.
#
# **13.	What is sampling without replacement? Give example.**
#
# Sampling without replacement is a method of selecting items from a population without returning them to the population after each selection. This affects the probabilities of subsequent selections.
#
# Example: Drawing cards from a deck without returning them after each draw.
#
# **14.	What is hypothesis? Give example.**
#
# A hypothesis is a statement or proposition that can be tested or investigated to determine its validity. In statistics, hypotheses are used to make inferences about populations based on sample data.
#
# Example: Hypothesis testing might involve stating that a new drug has no effect (null hypothesis) and gathering data to determine if the drug indeed has an effect.
